# %% [markdown]
# <a href="https://colab.research.google.com/github/Vallidevibolla/Assignment-5/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt


y = np.linspace(-5,5,100)
x=(y*y)
plt.plot(x,y,label='$y^2=x$')
plt.xlabel('$x-axis$')
plt.ylabel('$y-axis$')

def line_gen(A,B):
  len =10
  dim = A.shape[0]
  x_AB = np.zeros((dim,len))
  lam_1 = np.linspace(0,1,len)
  for i in range(len):
    temp1 = A + lam_1[i]*(B-A)
    x_AB[:,i]= temp1.T
  return x_AB

def parab_gen(y,a):
    x = y**2
    return x

#Plotting axis
R=np.array([1,0])
S=np.array([0,1])
RS=line_gen(R,S)
plt.plot(RS[0,:],RS[1,:],'--',label='(1  0)x=1')

A=np.array([4,0])
B=np.array([0,1])
AB=line_gen(A,B)
plt.plot(AB[0,:],AB[1,:],'--',label='(1  0)x=4')


plt.plot(0,0,'o',color='r')
plt.text(-0.4,0.4,'c')



#Plotting directrix
#equation of directrix is given x=1 & x=4
K=np.array([0.75,1.25])
L=np.array([0.75,-0.25])
A=line_gen(K,L)
plt.plot(A[0,:],A[1,:],label='$directrix$')

plt.plot(0.75,1.25,'o')
plt.text(0.75,1.25,'K(0.75,1.25)')
plt.plot(0.75,-0.25,'o')
plt.text(0.75,-0.25,'L(0.75,-0.25)')

#plotting focus
plt.plot(2,0,'o',label='$focus$')
plt.text(2,0,'F(2,0)')
plt.legend(loc='best')
plt.grid()
plt.xlim([-4,5])
plt.ylim([4,-10])



plt.show()
